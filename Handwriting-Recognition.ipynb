# %%
import tensorflow as tf

# %%
# !pip install mltu
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/73.7 kB ? eta -:--:--
#    ---------------------- ----------------- 41.0/73.7 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 73.7/73.7 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB 3.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/5.6 MB 4.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/5.6 MB 6.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.6 MB 8.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.3/5.6 MB 10.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.6 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.6 MB 13.0 MB/s eta 0:00:01
# ...
